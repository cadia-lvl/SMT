# %% [markdown]
# # Bæta við mörkun og lemmun
# Hér er unnið með málheildirnar. Mörkun og lemmun er bætt við gögnin.
#
# Gert er ráð fyrir að það sé búið að sía gögnin.
# - Síuð gögn, `input_dir`
#
# Eftir að hafa keyrt reikniritið verður `target_dir` eftirfarandi.
# - `target_dir/x.tsv.(is|en)`, þar sem `x` hefur sama nafn og í `input_dir`.
# Það er, útkomurnar eru `.tsv` skjöl með þremur dálkum. Fyrsti dálkurinn er tilreiddur texti, annar dálkurinn eru mörk tókanna, þriðji er lemmur orðanna. Bil er skrifað á milli hvers tóka, marks og lemmu.
#
# Reikniritinu er skipt í eftirfarandi skref:
# 1. Uppsetning
# 2. Málheildir lesnar
# 3. Bætti við málheildir
# 4. Málheildir skrifaðar.

# %% [markdown]
# ## 1. Uppsetning

# %%
# The location of corpus to read
input_dir = '/work/haukurpj/data/filtered/Parice1.0'

# The location of where to write the results
target_dir = '/work/haukurpj/data/filtered/Parice1.0'

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import pathlib

input_dir = pathlib.Path(input_dir)
target_dir = pathlib.Path(target_dir)

assert input_dir.exists()
if not target_dir.parent.exists():
    target_dir.parent.mkdir()
    target_dir.mkdir()

# %% [markdown]
# ## 2. Málheildir lesnar

# %%
from typing import List, Tuple
Sentence = List
POS = List
Lemma = List

Corpus = List[Sentence]
langs = ['en', 'is']

EnrichedSentence = Tuple[Sentence, POS, Lemma]
EnrichedCorpus = List[EnrichedSentence]

# %%
def path_to_corpus(in_path: str) -> Corpus:
    with open(in_path) as f_in:
        return f_in.readlines()

# %%
from glob import glob

input_corpora = {
    'en': {
        corpus: path_to_corpus(corpus) for corpus in glob(f'{input_dir}/*.en')
    },
    'is': {
        corpus: path_to_corpus(corpus) for corpus in glob(f'{input_dir}/*.is')
    }
}

# %%
for lang in langs:
    input_corpora[lang].keys()
# Out:
# dict_keys(['/work/haukurpj/data/filtered/Parice1.0/test-opensubtitles.en', '/work/haukurpj/data/filtered/Parice1.0/test-ees.en', '/work/haukurpj/data/filtered/Parice1.0/train.en', '/work/haukurpj/data/filtered/Parice1.0/test-ema.en', '/work/haukurpj/data/filtered/Parice1.0/dev.en'])
# dict_keys(['/work/haukurpj/data/filtered/Parice1.0/test-opensubtitles.is', '/work/haukurpj/data/filtered/Parice1.0/test-ees.is', '/work/haukurpj/data/filtered/Parice1.0/test-ema.is', '/work/haukurpj/data/filtered/Parice1.0/train.is', '/work/haukurpj/data/filtered/Parice1.0/dev.is'])

# %% [markdown]
# ## 3. Bæta við mörkun og lemmun

# %%
from time import time
import requests
import nltk
#nltk.download('wordnet')
#nltk.download('averaged_perceptron_tagger')
from nltk.corpus import wordnet as wn
from nltk.stem.wordnet import WordNetLemmatizer
from nltk import word_tokenize, pos_tag
from collections import defaultdict

tag_map = defaultdict(lambda : wn.NOUN)
tag_map['J'] = wn.ADJ
tag_map['V'] = wn.VERB
tag_map['R'] = wn.ADV

def make_chunks(sentences, chunksize):
    for i in range(0, len(sentences), chunksize):
        yield sentences[i:i + chunksize]

def enrich_corpus(corpus: Corpus, lang: str, chunksize=4000) -> EnrichedCorpus:
    """Enrich the given corpus with POS and lemma.
    
    English processing is offline.
    Icelandic processing is done via online API.
    """
    fully_enriched_corpus = []
    function = None
    if lang == 'en':
        function = enrich_sentences_en
    elif lang == 'is':
        function = enrich_sentences_is
        
    for chunk in make_chunks(corpus, chunksize):
        start = time()
        fully_enriched_corpus.extend(function(chunk))
        end = time()
        print(f"Bulk enrichment took={end - start:.2f}")

    return fully_enriched_corpus

URL = 'http://malvinnsla.arnastofnun.is'

def enrich_sentences_is(corpus: Corpus) -> EnrichedCorpus:
    enriched_sentences = []
    json = requests.post(URL, data={
        'text': "".join(corpus),
        'lemma': 'on'
    }).json()
    for paragraph in json['paragraphs']:
        forms: Sentence = []
        poss: POS = []
        lemmas: Lemma = []
        for sentence in paragraph['sentences']:
            for token in sentence:
                forms.append(token['word'])
                poss.append(token['tag'])
                lemmas.append(token['lemma'])
        enriched_sentences.append((forms, poss, lemmas))
    return enriched_sentences

def enrich_sentences_en(corpus: Corpus) -> EnrichedSentence:
    lmtzr = WordNetLemmatizer()
    enriched_sentences = []
    for sentence in corpus:
        forms: Sentence = []
        poss: POS = []
        lemmas: Lemma = []
        tokens = word_tokenize(sentence)
        for token, tag in pos_tag(tokens):
            lemma = lmtzr.lemmatize(token, tag_map[tag[0]])
            forms.append(token)
            poss.append(tag)
            lemmas.append(lemma.lower())
        enriched_sentences.append((forms, poss, lemmas))
    return enriched_sentences

# %%
import requests
def test_api(sentences):
    return requests.post(URL, data={
        'text': "".join(sentences),
        'lemma': 'on'
    }).json()

test = ["Einn. Tveir.\n","Þrír.\n"]
test_api(test)
# Out:
# {'paragraphs': [{'sentences': [[{'lemma': 'einn',
#       'tag': 'tfken',
#       'word': 'Einn'},
#      {'lemma': '.', 'tag': '.', 'word': '.'}],
#     [{'lemma': 'tveir', 'tag': 'tfkfn', 'word': 'Tveir'},
#      {'lemma': '.', 'tag': '.', 'word': '.'}]]},
#   {'sentences': [[{'lemma': 'þrír', 'tag': 'tfkfn', 'word': 'Þrír'},
#      {'lemma': '.', 'tag': '.', 'word': '.'}]]}]}

# %%
test = ['One. Two.\n', 'Three.\n']
enrich_corpus(test, 'en', chunksize=2)
# Out:
# Bulk enrichment took=0.00
# [(['One', '.', 'Two', '.'], ['CD', '.', 'CD', '.'], ['one', '.', 'two', '.']),
#  (['Three', '.'], ['CD', '.'], ['three', '.'])]

# %%
def map_to_target(input_file, target_dir):
    input_file = pathlib.Path(input_file)
    return pathlib.Path(target_dir).joinpath(f'{input_file.stem}.{input_file.suffix}.tsv')

enriched_corpus = {lang: {
    map_to_target(corpus_path, target_dir): enrich_corpus(input_corpora[lang][corpus_path], lang, chunksize=4000) for corpus_path in input_corpora[lang]}
for lang in langs}
# Out:
# Bulk enrichment took=0.94
# Bulk enrichment took=1.45
# Bulk enrichment took=2.56
# Bulk enrichment took=2.38
# Bulk enrichment took=3.52
# Bulk enrichment took=2.11
# Bulk enrichment took=2.18
# Bulk enrichment took=2.23
# Bulk enrichment took=2.63
# Bulk enrichment took=2.30
# Bulk enrichment took=2.09
# Bulk enrichment took=2.09
# Bulk enrichment took=1.71
# Bulk enrichment took=1.62
# Bulk enrichment took=2.26
# Bulk enrichment took=2.41
# Bulk enrichment took=2.37
# Bulk enrichment took=2.33
# Bulk enrichment took=1.87
# Bulk enrichment took=1.92
# Bulk enrichment took=1.89
# Bulk enrichment took=3.57
# Bulk enrichment took=3.20
# Bulk enrichment took=3.52
# Bulk enrichment took=3.79
# Bulk enrichment took=3.45
# Bulk enrichment took=2.61
# Bulk enrichment took=3.31
# Bulk enrichment took=2.70
# Bulk enrichment took=3.23
# Bulk enrichment took=3.35
# Bulk enrichment took=3.66
# Bulk enrichment took=3.41
# Bulk enrichment took=3.44
# Bulk enrichment took=3.72
# Bulk enrichment took=3.06
# Bulk enrichment took=3.15
# Bulk enrichment took=3.59
# Bulk enrichment took=3.03
# Bulk enrichment took=2.91
# Bulk enrichment took=3.01
# Bulk enrichment took=3.32
# Bulk enrichment took=3.04
# Bulk enrichment took=4.32
# Bulk enrichment took=3.29
# Bulk enrichment took=3.36
# Bulk enrichment took=3.49
# Bulk enrichment took=3.75
# Bulk enrichment took=3.26
# Bulk enrichment took=2.57
# Bulk enrichment took=3.34
# Bulk enrichment took=3.36
# Bulk enrichment took=3.15
# Bulk enrichment took=3.06
# Bulk enrichment took=3.47
# Bulk enrichment took=3.35
# Bulk enrichment took=3.09
# Bulk enrichment took=3.70
# Bulk enrichment took=3.08
# Bulk enrichment took=3.26
# Bulk enrichment took=2.98
# Bulk enrichment took=4.29
# Bulk enrichment took=3.37
# Bulk enrichment took=3.50
# Bulk enrichment took=2.82
# Bulk enrichment took=3.01
# Bulk enrichment took=3.33
# Bulk enrichment took=3.51
# Bulk enrichment took=3.50
# Bulk enrichment took=3.55
# Bulk enrichment took=2.96
# Bulk enrichment took=3.47
# Bulk enrichment took=2.97
# Bulk enrichment took=3.14
# Bulk enrichment took=3.51
# Bulk enrichment took=3.33
# Bulk enrichment took=3.33
# Bulk enrichment took=3.00
# Bulk enrichment took=3.06
# Bulk enrichment took=3.45
# Bulk enrichment took=2.90
# Bulk enrichment took=3.92
# Bulk enrichment took=3.65
# Bulk enrichment took=4.46
# Bulk enrichment took=4.07
# Bulk enrichment took=2.93
# Bulk enrichment took=3.46
# Bulk enrichment took=2.92
# Bulk enrichment took=2.85
# Bulk enrichment took=3.49
# Bulk enrichment took=3.51
# Bulk enrichment took=3.64
# Bulk enrichment took=2.85
# Bulk enrichment took=2.87
# Bulk enrichment took=2.72
# Bulk enrichment took=3.25
# Bulk enrichment took=3.04
# Bulk enrichment took=3.41
# Bulk enrichment took=3.54
# Bulk enrichment took=3.43
# Bulk enrichment took=3.42
# Bulk enrichment took=3.65
# Bulk enrichment took=2.77
# Bulk enrichment took=3.45
# Bulk enrichment took=3.23
# Bulk enrichment took=3.80
# Bulk enrichment took=3.74
# Bulk enrichment took=3.28
# Bulk enrichment took=3.04
# Bulk enrichment took=3.38
# Bulk enrichment took=3.43
# Bulk enrichment took=4.47
# Bulk enrichment took=3.28
# Bulk enrichment took=3.38
# Bulk enrichment took=3.85
# Bulk enrichment took=3.14
# Bulk enrichment took=3.40
# Bulk enrichment took=3.45
# Bulk enrichment took=3.06
# Bulk enrichment took=3.24
# Bulk enrichment took=3.44
# Bulk enrichment took=3.39
# Bulk enrichment took=3.51
# Bulk enrichment took=2.00
# Bulk enrichment took=3.14
# Bulk enrichment took=3.68
# Bulk enrichment took=3.32
# Bulk enrichment took=3.73
# Bulk enrichment took=3.20
# Bulk enrichment took=3.67
# Bulk enrichment took=3.46
# Bulk enrichment took=4.08
# Bulk enrichment took=3.64
# Bulk enrichment took=3.49
# Bulk enrichment took=3.66
# Bulk enrichment took=3.50
# Bulk enrichment took=3.83
# Bulk enrichment took=3.67
# Bulk enrichment took=2.67
# Bulk enrichment took=2.62
# Bulk enrichment took=3.11
# Bulk enrichment took=3.61
# Bulk enrichment took=3.48
# Bulk enrichment took=3.60
# Bulk enrichment took=3.59
# Bulk enrichment took=3.60
# Bulk enrichment took=5.14
# Bulk enrichment took=3.24
# Bulk enrichment took=3.64
# Bulk enrichment took=3.14
# Bulk enrichment took=3.23
# Bulk enrichment took=3.52
# Bulk enrichment took=3.27
# Bulk enrichment took=3.32
# Bulk enrichment took=3.04
# Bulk enrichment took=3.80
# Bulk enrichment took=3.70
# Bulk enrichment took=3.55
# Bulk enrichment took=3.30
# Bulk enrichment took=3.58
# Bulk enrichment took=3.53
# Bulk enrichment took=3.44
# Bulk enrichment took=3.71
# Bulk enrichment took=3.37
# Bulk enrichment took=3.40
# Bulk enrichment took=3.25
# Bulk enrichment took=3.58
# Bulk enrichment took=3.23
# Bulk enrichment took=3.32
# Bulk enrichment took=3.50
# Bulk enrichment took=3.33
# Bulk enrichment took=3.45
# Bulk enrichment took=3.37
# Bulk enrichment took=3.52
# Bulk enrichment took=3.27
# Bulk enrichment took=3.51
# Bulk enrichment took=3.26
# Bulk enrichment took=3.04
# Bulk enrichment took=3.76
# Bulk enrichment took=3.32
# Bulk enrichment took=3.66
# Bulk enrichment took=3.09
# Bulk enrichment took=2.95
# Bulk enrichment took=3.63
# Bulk enrichment took=2.66
# Bulk enrichment took=2.79
# Bulk enrichment took=3.63
# Bulk enrichment took=3.62
# Bulk enrichment took=3.63
# Bulk enrichment took=3.58
# Bulk enrichment took=5.52
# Bulk enrichment took=3.53
# Bulk enrichment took=3.31
# Bulk enrichment took=3.31
# Bulk enrichment took=3.52
# Bulk enrichment took=3.75
# Bulk enrichment took=3.36
# Bulk enrichment took=3.20
# Bulk enrichment took=3.42
# Bulk enrichment took=3.24
# Bulk enrichment took=3.28
# Bulk enrichment took=3.58
# Bulk enrichment took=2.91
# Bulk enrichment took=3.25
# Bulk enrichment took=3.48
# Bulk enrichment took=3.78
# Bulk enrichment took=2.89
# Bulk enrichment took=3.58
# Bulk enrichment took=3.56
# Bulk enrichment took=3.55
# Bulk enrichment took=3.64
# Bulk enrichment took=3.46
# Bulk enrichment took=2.23
# Bulk enrichment took=3.26
# Bulk enrichment took=3.13
# Bulk enrichment took=3.47
# Bulk enrichment took=3.53
# Bulk enrichment took=3.59
# Bulk enrichment took=3.40
# Bulk enrichment took=3.82
# Bulk enrichment took=3.64
# Bulk enrichment took=3.76
# Bulk enrichment took=3.57
# Bulk enrichment took=3.54
# Bulk enrichment took=2.79
# Bulk enrichment took=3.12
# Bulk enrichment took=3.52
# Bulk enrichment took=3.74
# Bulk enrichment took=3.30
# Bulk enrichment took=3.13
# Bulk enrichment took=3.27
# Bulk enrichment took=3.32
# Bulk enrichment took=3.66
# Bulk enrichment took=3.53
# Bulk enrichment took=3.41
# Bulk enrichment took=3.82
# Bulk enrichment took=3.38
# Bulk enrichment took=3.06
# Bulk enrichment took=3.42
# Bulk enrichment took=3.43
# Bulk enrichment took=3.04
# Bulk enrichment took=3.06
# Bulk enrichment took=3.42
# Bulk enrichment took=3.32
# Bulk enrichment took=3.33
# Bulk enrichment took=5.93
# Bulk enrichment took=3.60
# Bulk enrichment took=3.36
# Bulk enrichment took=3.81
# Bulk enrichment took=3.20
# Bulk enrichment took=3.38
# Bulk enrichment took=3.69
# Bulk enrichment took=3.66
# Bulk enrichment took=3.47
# Bulk enrichment took=3.86
# Bulk enrichment took=3.58
# Bulk enrichment took=3.70
# Bulk enrichment took=3.40
# Bulk enrichment took=2.20
# Bulk enrichment took=1.80
# Bulk enrichment took=1.75
# Bulk enrichment took=3.45
# Bulk enrichment took=2.95
# Bulk enrichment took=3.02
# Bulk enrichment took=2.97
# Bulk enrichment took=2.86
# Bulk enrichment took=3.06
# Bulk enrichment took=3.00
# Bulk enrichment took=2.86
# Bulk enrichment took=2.47
# Bulk enrichment took=2.84
# Bulk enrichment took=2.59
# Bulk enrichment took=2.73
# Bulk enrichment took=2.57
# Bulk enrichment took=2.45
# Bulk enrichment took=2.36
# Bulk enrichment took=2.41
# Bulk enrichment took=2.83
# Bulk enrichment took=2.39
# Bulk enrichment took=2.45
# Bulk enrichment took=2.27
# Bulk enrichment took=2.39
# Bulk enrichment took=2.80
# Bulk enrichment took=3.07
# Bulk enrichment took=2.71
# Bulk enrichment took=2.49
# Bulk enrichment took=1.83
# Bulk enrichment took=2.78
# Bulk enrichment took=3.21
# Bulk enrichment took=3.01
# Bulk enrichment took=2.70
# Bulk enrichment took=2.44
# Bulk enrichment took=4.20
# Bulk enrichment took=3.88
# Bulk enrichment took=3.94
# Bulk enrichment took=3.35
# Bulk enrichment took=2.44
# Bulk enrichment took=2.53
# Bulk enrichment took=2.56
# Bulk enrichment took=2.55
# Bulk enrichment took=2.44
# Bulk enrichment took=2.52
# Bulk enrichment took=2.38
# Bulk enrichment took=2.67
# Bulk enrichment took=2.54
# Bulk enrichment took=2.87
# Bulk enrichment took=2.15
# Bulk enrichment took=2.62
# Bulk enrichment took=3.43
# Bulk enrichment took=2.56
# Bulk enrichment took=2.52
# Bulk enrichment took=2.45
# Bulk enrichment took=2.43
# Bulk enrichment took=5.49
# Bulk enrichment took=2.50
# Bulk enrichment took=2.94
# Bulk enrichment took=2.47
# Bulk enrichment took=2.59
# Bulk enrichment took=2.68
# Bulk enrichment took=2.55
# Bulk enrichment took=2.75
# Bulk enrichment took=3.05
# Bulk enrichment took=3.54
# Bulk enrichment took=3.25
# Bulk enrichment took=3.55
# Bulk enrichment took=3.21
# Bulk enrichment took=3.02
# Bulk enrichment took=2.98
# Bulk enrichment took=2.70
# Bulk enrichment took=2.92
# Bulk enrichment took=2.67
# Bulk enrichment took=2.59
# Bulk enrichment took=2.81
# Bulk enrichment took=2.69
# Bulk enrichment took=2.41
# Bulk enrichment took=2.03
# Bulk enrichment took=2.40
# Bulk enrichment took=2.98
# Bulk enrichment took=2.48
# Bulk enrichment took=2.66
# Bulk enrichment took=3.21
# Bulk enrichment took=3.70
# Bulk enrichment took=3.77
# Bulk enrichment took=3.16
# Bulk enrichment took=3.14
# Bulk enrichment took=3.09
# Bulk enrichment took=2.73
# Bulk enrichment took=2.58
# Bulk enrichment took=1.58
# Bulk enrichment took=1.38
# Bulk enrichment took=1.40
# Bulk enrichment took=1.58
# Bulk enrichment took=1.38
# Bulk enrichment took=1.41
# Bulk enrichment took=1.43
# Bulk enrichment took=1.51
# Bulk enrichment took=1.55
# Bulk enrichment took=1.30
# Bulk enrichment took=1.39
# Bulk enrichment took=1.46
# Bulk enrichment took=1.37
# Bulk enrichment took=1.42
# Bulk enrichment took=1.42
# Bulk enrichment took=1.38
# Bulk enrichment took=1.44
# Bulk enrichment took=1.47
# Bulk enrichment took=1.44
# Bulk enrichment took=1.48
# Bulk enrichment took=1.49
# Bulk enrichment took=1.44
# Bulk enrichment took=1.44
# Bulk enrichment took=1.43
# Bulk enrichment took=1.45
# Bulk enrichment took=1.40
# Bulk enrichment took=1.46
# Bulk enrichment took=1.46
# Bulk enrichment took=1.44
# Bulk enrichment took=1.41
# Bulk enrichment took=1.40
# Bulk enrichment took=1.43
# Bulk enrichment took=1.42
# Bulk enrichment took=1.40
# Bulk enrichment took=1.40
# Bulk enrichment took=1.36
# Bulk enrichment took=1.39
# Bulk enrichment took=1.47
# Bulk enrichment took=1.36
# Bulk enrichment took=1.36
# Bulk enrichment took=1.37
# Bulk enrichment took=1.38
# Bulk enrichment took=1.51
# Bulk enrichment took=1.36
# Bulk enrichment took=1.42
# Bulk enrichment took=1.45
# Bulk enrichment took=1.36
# Bulk enrichment took=1.42
# Bulk enrichment took=1.41
# Bulk enrichment took=1.43
# Bulk enrichment took=4.67
# Bulk enrichment took=1.36
# Bulk enrichment took=1.41
# Bulk enrichment took=1.40
# Bulk enrichment took=1.46
# Bulk enrichment took=1.53
# Bulk enrichment took=1.38
# Bulk enrichment took=1.46
# Bulk enrichment took=1.43
# Bulk enrichment took=1.42
# Bulk enrichment took=1.48
# Bulk enrichment took=1.49
# Bulk enrichment took=1.54
# Bulk enrichment took=1.48
# Bulk enrichment took=1.56
# Bulk enrichment took=1.43
# Bulk enrichment took=1.47
# Bulk enrichment took=1.52
# Bulk enrichment took=1.47
# Bulk enrichment took=1.54
# Bulk enrichment took=1.52
# Bulk enrichment took=1.47
# Bulk enrichment took=1.42
# Bulk enrichment took=1.55
# Bulk enrichment took=1.43
# Bulk enrichment took=1.36
# Bulk enrichment took=1.45
# Bulk enrichment took=1.47
# Bulk enrichment took=1.40
# Bulk enrichment took=1.42
# Bulk enrichment took=1.45
# Bulk enrichment took=1.50
# Bulk enrichment took=1.48
# Bulk enrichment took=1.45
# Bulk enrichment took=1.39
# Bulk enrichment took=1.47
# Bulk enrichment took=1.46
# Bulk enrichment took=1.48
# Bulk enrichment took=1.48
# Bulk enrichment took=1.50
# Bulk enrichment took=1.53
# Bulk enrichment took=1.55
# Bulk enrichment took=1.40
# Bulk enrichment took=1.55
# Bulk enrichment took=1.47
# Bulk enrichment took=1.51
# Bulk enrichment took=1.44
# Bulk enrichment took=1.54
# Bulk enrichment took=1.46
# Bulk enrichment took=1.44
# Bulk enrichment took=1.60
# Bulk enrichment took=1.59
# Bulk enrichment took=1.46
# Bulk enrichment took=1.51
# Bulk enrichment took=1.54
# Bulk enrichment took=1.60
# Bulk enrichment took=1.56
# Bulk enrichment took=1.49
# Bulk enrichment took=1.61
# Bulk enrichment took=1.59
# Bulk enrichment took=1.46
# Bulk enrichment took=1.46
# Bulk enrichment took=1.56
# Bulk enrichment took=1.56
# Bulk enrichment took=1.61
# Bulk enrichment took=1.48
# Bulk enrichment took=1.59
# Bulk enrichment took=1.50
# Bulk enrichment took=1.53
# Bulk enrichment took=1.52
# Bulk enrichment took=1.59
# Bulk enrichment took=1.51
# Bulk enrichment took=1.49
# Bulk enrichment took=1.47
# Bulk enrichment took=1.50
# Bulk enrichment took=1.58
# Bulk enrichment took=1.52
# Bulk enrichment took=1.56
# Bulk enrichment took=1.59
# Bulk enrichment took=1.73
# Bulk enrichment took=1.56
# Bulk enrichment took=1.48
# Bulk enrichment took=1.44
# Bulk enrichment took=1.52
# Bulk enrichment took=2.34
# Bulk enrichment took=1.65
# Bulk enrichment took=1.54
# Bulk enrichment took=1.54
# Bulk enrichment took=1.50
# Bulk enrichment took=1.59
# Bulk enrichment took=1.49
# Bulk enrichment took=1.53
# Bulk enrichment took=1.52
# Bulk enrichment took=1.97
# Bulk enrichment took=1.60
# Bulk enrichment took=1.59
# Bulk enrichment took=1.60
# Bulk enrichment took=1.61
# Bulk enrichment took=1.52
# Bulk enrichment took=1.50
# Bulk enrichment took=1.54
# Bulk enrichment took=1.52
# Bulk enrichment took=1.58
# Bulk enrichment took=1.56
# Bulk enrichment took=1.52
# Bulk enrichment took=1.53
# Bulk enrichment took=1.50
# Bulk enrichment took=5.30
# Bulk enrichment took=1.54
# Bulk enrichment took=1.54
# Bulk enrichment took=1.57
# Bulk enrichment took=1.54
# Bulk enrichment took=1.54
# Bulk enrichment took=1.60
# Bulk enrichment took=1.61
# Bulk enrichment took=1.54
# Bulk enrichment took=1.56
# Bulk enrichment took=1.59
# Bulk enrichment took=1.44
# Bulk enrichment took=1.55
# Bulk enrichment took=3.05
# Bulk enrichment took=1.54
# Bulk enrichment took=1.49
# Bulk enrichment took=1.55
# Bulk enrichment took=1.50
# Bulk enrichment took=1.43
# Bulk enrichment took=1.55
# Bulk enrichment took=1.52
# Bulk enrichment took=1.46
# Bulk enrichment took=2.43
# Bulk enrichment took=1.57
# Bulk enrichment took=1.56
# Bulk enrichment took=1.57
# Bulk enrichment took=1.61
# Bulk enrichment took=1.54
# Bulk enrichment took=1.52
# Bulk enrichment took=1.48
# Bulk enrichment took=1.60
# Bulk enrichment took=1.49
# Bulk enrichment took=1.47
# Bulk enrichment took=1.55
# Bulk enrichment took=1.55
# Bulk enrichment took=1.61
# Bulk enrichment took=1.48
# Bulk enrichment took=1.60
# Bulk enrichment took=1.56
# Bulk enrichment took=1.62
# Bulk enrichment took=1.60
# Bulk enrichment took=1.60
# Bulk enrichment took=1.50
# Bulk enrichment took=1.50
# Bulk enrichment took=1.55
# Bulk enrichment took=1.58
# Bulk enrichment took=1.53
# Bulk enrichment took=1.59
# Bulk enrichment took=1.67
# Bulk enrichment took=1.63
# Bulk enrichment took=1.58
# Bulk enrichment took=1.65
# Bulk enrichment took=1.55
# Bulk enrichment took=1.46
# Bulk enrichment took=1.49
# Bulk enrichment took=1.54
# Bulk enrichment took=1.54
# Bulk enrichment took=1.46
# Bulk enrichment took=1.57
# Bulk enrichment took=1.60
# Bulk enrichment took=2.43
# Bulk enrichment took=1.59
# Bulk enrichment took=1.71
# Bulk enrichment took=1.53
# Bulk enrichment took=1.52
# Bulk enrichment took=1.53
# Bulk enrichment took=1.52
# Bulk enrichment took=1.58
# Bulk enrichment took=1.59
# Bulk enrichment took=1.60
# Bulk enrichment took=1.56
# Bulk enrichment took=1.47
# Bulk enrichment took=1.54
# Bulk enrichment took=1.49
# Bulk enrichment took=1.59
# Bulk enrichment took=1.51
# Bulk enrichment took=1.37
# Bulk enrichment took=1.24
# Bulk enrichment took=1.14
# Bulk enrichment took=1.29
# Bulk enrichment took=1.09
# Bulk enrichment took=7.04
# Bulk enrichment took=22.45
# Bulk enrichment took=20.08
# Bulk enrichment took=41.87
# Bulk enrichment took=35.14
# Bulk enrichment took=43.44
# Bulk enrichment took=29.60
# Bulk enrichment took=29.28
# Bulk enrichment took=29.15
# Bulk enrichment took=32.38
# Bulk enrichment took=33.38
# Bulk enrichment took=29.46
# Bulk enrichment took=28.63
# Bulk enrichment took=20.85
# Bulk enrichment took=19.14
# Bulk enrichment took=29.26
# Bulk enrichment took=32.17
# Bulk enrichment took=32.35
# Bulk enrichment took=25.39
# Bulk enrichment took=26.41
# Bulk enrichment took=27.61
# Bulk enrichment took=26.98
# Bulk enrichment took=54.62
# Bulk enrichment took=50.71
# Bulk enrichment took=59.03
# Bulk enrichment took=58.25
# Bulk enrichment took=55.47
# Bulk enrichment took=40.01
# Bulk enrichment took=54.61
# Bulk enrichment took=43.72
# Bulk enrichment took=37.45
# Bulk enrichment took=52.66
# Bulk enrichment took=60.82
# Bulk enrichment took=56.16
# Bulk enrichment took=55.83
# Bulk enrichment took=60.59
# Bulk enrichment took=48.90
# Bulk enrichment took=51.40
# Bulk enrichment took=58.64
# Bulk enrichment took=47.09
# Bulk enrichment took=46.84
# Bulk enrichment took=43.96
# Bulk enrichment took=54.73
# Bulk enrichment took=50.20
# Bulk enrichment took=60.36
# Bulk enrichment took=52.39
# Bulk enrichment took=54.99
# Bulk enrichment took=55.63
# Bulk enrichment took=59.02
# Bulk enrichment took=53.69
# Bulk enrichment took=39.47
# Bulk enrichment took=54.40
# Bulk enrichment took=55.49
# Bulk enrichment took=52.38
# Bulk enrichment took=51.11
# Bulk enrichment took=58.68
# Bulk enrichment took=56.84
# Bulk enrichment took=49.37
# Bulk enrichment took=61.44
# Bulk enrichment took=47.76
# Bulk enrichment took=54.27
# Bulk enrichment took=48.68
# Bulk enrichment took=55.99
# Bulk enrichment took=57.38
# Bulk enrichment took=59.22
# Bulk enrichment took=43.38
# Bulk enrichment took=49.17
# Bulk enrichment took=55.30
# Bulk enrichment took=55.02
# Bulk enrichment took=56.05
# Bulk enrichment took=61.20
# Bulk enrichment took=45.55
# Bulk enrichment took=58.33
# Bulk enrichment took=47.26
# Bulk enrichment took=57.70
# Bulk enrichment took=63.21
# Bulk enrichment took=56.36
# Bulk enrichment took=55.02
# Bulk enrichment took=47.75
# Bulk enrichment took=49.29
# Bulk enrichment took=58.63
# Bulk enrichment took=45.59
# Bulk enrichment took=60.19
# Bulk enrichment took=57.16
# Bulk enrichment took=54.51
# Bulk enrichment took=53.98
# Bulk enrichment took=45.72
# Bulk enrichment took=53.49
# Bulk enrichment took=44.13
# Bulk enrichment took=42.44
# Bulk enrichment took=56.44
# Bulk enrichment took=58.53
# Bulk enrichment took=59.90
# Bulk enrichment took=46.57
# Bulk enrichment took=42.91
# Bulk enrichment took=42.51
# Bulk enrichment took=53.30
# Bulk enrichment took=47.08
# Bulk enrichment took=56.59
# Bulk enrichment took=60.00
# Bulk enrichment took=56.77
# Bulk enrichment took=57.20
# Bulk enrichment took=63.06
# Bulk enrichment took=42.27
# Bulk enrichment took=56.83
# Bulk enrichment took=50.68
# Bulk enrichment took=64.11
# Bulk enrichment took=65.32
# Bulk enrichment took=53.28
# Bulk enrichment took=47.37
# Bulk enrichment took=57.64
# Bulk enrichment took=56.34
# Bulk enrichment took=52.38
# Bulk enrichment took=53.34
# Bulk enrichment took=55.76
# Bulk enrichment took=68.61
# Bulk enrichment took=49.99
# Bulk enrichment took=55.30
# Bulk enrichment took=62.58
# Bulk enrichment took=47.46
# Bulk enrichment took=50.34
# Bulk enrichment took=56.66
# Bulk enrichment took=59.24
# Bulk enrichment took=60.26
# Bulk enrichment took=26.62
# Bulk enrichment took=51.55
# Bulk enrichment took=61.16
# Bulk enrichment took=52.08
# Bulk enrichment took=62.03
# Bulk enrichment took=50.04
# Bulk enrichment took=61.33
# Bulk enrichment took=55.55
# Bulk enrichment took=66.18
# Bulk enrichment took=57.92
# Bulk enrichment took=57.26
# Bulk enrichment took=63.01
# Bulk enrichment took=60.74
# Bulk enrichment took=62.86
# Bulk enrichment took=64.49
# Bulk enrichment took=40.90
# Bulk enrichment took=41.25
# Bulk enrichment took=49.27
# Bulk enrichment took=57.93
# Bulk enrichment took=56.09
# Bulk enrichment took=58.46
# Bulk enrichment took=62.04
# Bulk enrichment took=63.65
# Bulk enrichment took=62.21
# Bulk enrichment took=51.07
# Bulk enrichment took=60.76
# Bulk enrichment took=50.12
# Bulk enrichment took=53.70
# Bulk enrichment took=58.96
# Bulk enrichment took=52.31
# Bulk enrichment took=56.00
# Bulk enrichment took=47.94
# Bulk enrichment took=64.38
# Bulk enrichment took=62.29
# Bulk enrichment took=61.29
# Bulk enrichment took=54.30
# Bulk enrichment took=62.41
# Bulk enrichment took=61.68
# Bulk enrichment took=56.52
# Bulk enrichment took=67.20
# Bulk enrichment took=55.72
# Bulk enrichment took=58.24
# Bulk enrichment took=53.45
# Bulk enrichment took=55.55
# Bulk enrichment took=52.55
# Bulk enrichment took=57.76
# Bulk enrichment took=61.34
# Bulk enrichment took=54.72
# Bulk enrichment took=56.45
# Bulk enrichment took=57.17
# Bulk enrichment took=58.27
# Bulk enrichment took=52.67
# Bulk enrichment took=59.83
# Bulk enrichment took=50.93
# Bulk enrichment took=46.18
# Bulk enrichment took=64.11
# Bulk enrichment took=54.83
# Bulk enrichment took=63.08
# Bulk enrichment took=47.80
# Bulk enrichment took=46.90
# Bulk enrichment took=63.24
# Bulk enrichment took=39.61
# Bulk enrichment took=41.71
# Bulk enrichment took=57.17
# Bulk enrichment took=58.77
# Bulk enrichment took=59.51
# Bulk enrichment took=57.71
# Bulk enrichment took=59.05
# Bulk enrichment took=56.69
# Bulk enrichment took=52.24
# Bulk enrichment took=51.86
# Bulk enrichment took=52.78
# Bulk enrichment took=62.48
# Bulk enrichment took=54.99
# Bulk enrichment took=50.28
# Bulk enrichment took=53.83
# Bulk enrichment took=52.86
# Bulk enrichment took=57.36
# Bulk enrichment took=60.87
# Bulk enrichment took=45.73
# Bulk enrichment took=53.21
# Bulk enrichment took=57.69
# Bulk enrichment took=65.52
# Bulk enrichment took=45.44
# Bulk enrichment took=57.77
# Bulk enrichment took=57.96
# Bulk enrichment took=62.10
# Bulk enrichment took=61.94
# Bulk enrichment took=57.77
# Bulk enrichment took=30.04
# Bulk enrichment took=49.95
# Bulk enrichment took=49.04
# Bulk enrichment took=54.27
# Bulk enrichment took=60.04
# Bulk enrichment took=65.24
# Bulk enrichment took=56.80
# Bulk enrichment took=64.68
# Bulk enrichment took=58.81
# Bulk enrichment took=64.71
# Bulk enrichment took=61.34
# Bulk enrichment took=57.96
# Bulk enrichment took=42.45
# Bulk enrichment took=51.00
# Bulk enrichment took=57.88
# Bulk enrichment took=64.95
# Bulk enrichment took=56.31
# Bulk enrichment took=51.56
# Bulk enrichment took=51.59
# Bulk enrichment took=48.43
# Bulk enrichment took=60.47
# Bulk enrichment took=59.26
# Bulk enrichment took=58.13
# Bulk enrichment took=65.08
# Bulk enrichment took=55.96
# Bulk enrichment took=47.02
# Bulk enrichment took=54.00
# Bulk enrichment took=59.79
# Bulk enrichment took=48.85
# Bulk enrichment took=45.22
# Bulk enrichment took=53.56
# Bulk enrichment took=56.86
# Bulk enrichment took=56.00
# Bulk enrichment took=57.53
# Bulk enrichment took=56.77
# Bulk enrichment took=58.21
# Bulk enrichment took=57.96
# Bulk enrichment took=52.52

# %%
import pickle

with open(f'{target_dir}/filtered.pickle', 'wb') as handle:
    pickle.dump(fix_enriched_corpus, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# !ls {target_dir}
# Out:
# dev.en		 test-ees.en  test-ema.is	     tmp.pickle
# dev.is		 test-ees.is  test-opensubtitles.en  train.en
# filtered.pickle  test-ema.en  test-opensubtitles.is  train.is

# %%
import pickle
with open(f'{target_dir}/tmp.pickle', 'rb') as handle:
    enriched_corpus = pickle.load(handle)

# %%
fix_enriched_corpus = {}
for lang in enriched_corpus.keys():
    fix_enriched_corpus[lang] = {}
    for corpus_path in enriched_corpus[lang]:
        name, _, lang, _ = pathlib.Path(corpus_path).name.split('.')
        fix_enriched_corpus[lang][".".join([name, lang])] = enriched_corpus[lang][corpus_path]

# %%
for lang in fix_enriched_corpus.keys():
    for corpus_name in fix_enriched_corpus[lang]:
        corpus_name
        fix_enriched_corpus[lang][corpus_name][:2]
# Out:
# 'test-opensubtitles.en'
# [(['Somebody',
#    'threw',
#    'a',
#    'brick',
#    'through',
#    'Meyer',
#    'Blum',
#    "'s",
#    'window',
#    'last',
#    'night',
#    '.'],
#   ['NN', 'VBD', 'DT', 'NN', 'IN', 'NNP', 'NNP', 'POS', 'NN', 'JJ', 'NN', '.'],
#   ['somebody',
#    'throw',
#    'a',
#    'brick',
#    'through',
#    'meyer',
#    'blum',
#    "'s",
#    'window',
#    'last',
#    'night',
#    '.']),
#  (['They', 'ai', "n't", 'gon', 'na', 'be', 'so', 'bad', '.'],
#   ['PRP', 'VBP', 'RB', 'VB', 'TO', 'VB', 'RB', 'JJ', '.'],
#   ['they', 'ai', "n't", 'gon', 'na', 'be', 'so', 'bad', '.'])]
# 'test-ees.en'
# [(['Whereas',
#    'Chapter',
#    '6',
#    'of',
#    'Annex',
#    'I',
#    'to',
#    'Directive',
#    '92/118/EEC',
#    'lays',
#    'down',
#    'requirements',
#    'for',
#    'the',
#    'importation',
#    'of',
#    'processed',
#    'animal',
#    'protein',
#    ';'],
#   ['NNP',
#    'NNP',
#    'CD',
#    'IN',
#    'NNP',
#    'PRP',
#    'TO',
#    'VB',
#    'CD',
#    'NNS',
#    'RP',
#    'NNS',
#    'IN',
#    'DT',
#    'NN',
#    'IN',
#    'VBN',
#    'JJ',
#    'NN',
#    ':'],
#   ['whereas',
#    'chapter',
#    '6',
#    'of',
#    'annex',
#    'i',
#    'to',
#    'directive',
#    '92/118/eec',
#    'lay',
#    'down',
#    'requirement',
#    'for',
#    'the',
#    'importation',
#    'of',
#    'process',
#    'animal',
#    'protein',
#    ';']),
#  (['Whereas',
#    'Commission',
#    'Decision',
#    '94/278/EC',
#    '(',
#    '3',
#    ')',
#    ',',
#    'as',
#    'last',
#    'amended',
#    'by',
#    'Decision',
#    '96/344/EC',
#    '(',
#    '4',
#    ')',
#    ',',
#    'has',
#    'laid',
#    'down',
#    'a',
#    'list',
#    'of',
#    'third',
#    'countries',
#    'from',
#    'which',
#    'Member',
#    'States',
#    'shall',
#    'authorize',
#    'the',
#    'importation',
#    'of',
#    'processed',
#    'animal',
#    'protein',
#    'not',
#    'intended',
#    'for',
#    'human',
#    'consumption',
#    ';'],
#   ['NNP',
#    'NNP',
#    'NNP',
#    'CD',
#    '(',
#    'CD',
#    ')',
#    ',',
#    'IN',
#    'JJ',
#    'VBN',
#    'IN',
#    'NNP',
#    'CD',
#    '(',
#    'CD',
#    ')',
#    ',',
#    'VBZ',
#    'VBN',
#    'RP',
#    'DT',
#    'NN',
#    'IN',
#    'JJ',
#    'NNS',
#    'IN',
#    'WDT',
#    'NNP',
#    'NNPS',
#    'MD',
#    'VB',
#    'DT',
#    'NN',
#    'IN',
#    'VBN',
#    'NN',
#    'NN',
#    'RB',
#    'VBN',
#    'IN',
#    'JJ',
#    'NN',
#    ':'],
#   ['whereas',
#    'commission',
#    'decision',
#    '94/278/ec',
#    '(',
#    '3',
#    ')',
#    ',',
#    'a',
#    'last',
#    'amend',
#    'by',
#    'decision',
#    '96/344/ec',
#    '(',
#    '4',
#    ')',
#    ',',
#    'have',
#    'lay',
#    'down',
#    'a',
#    'list',
#    'of',
#    'third',
#    'country',
#    'from',
#    'which',
#    'member',
#    'states',
#    'shall',
#    'authorize',
#    'the',
#    'importation',
#    'of',
#    'process',
#    'animal',
#    'protein',
#    'not',
#    'intend',
#    'for',
#    'human',
#    'consumption',
#    ';'])]
# 'train.en'
# [(['BOOK', 'I'], ['NNP', 'PRP'], ['book', 'i']),
#  (['CHAPTER', 'I', 'A', 'FETE', 'AT', 'THE', 'NEW', 'PALACE'],
#   ['NN', 'PRP', 'VBP', 'NNP', 'NNP', 'NNP', 'NNP', 'NNP'],
#   ['chapter', 'i', 'a', 'fete', 'at', 'the', 'new', 'palace'])]
# 'test-ema.en'
# [(['(',
#    '2',
#    ')',
#    'TVC',
#    ':',
#    'includes',
#    'all',
#    'vaccinated',
#    'subjects',
#    '(',
#    'who',
#    'received',
#    'at',
#    'least',
#    'one',
#    'dose',
#    'of',
#    'vaccine',
#    ')',
#    'irrespective',
#    'of',
#    'HPV',
#    'DNA',
#    'status',
#    ',',
#    'cytology',
#    'and',
#    'serostatus',
#    'at',
#    'baseline',
#    '.'],
#   ['(',
#    'CD',
#    ')',
#    'NN',
#    ':',
#    'VBZ',
#    'DT',
#    'JJ',
#    'NNS',
#    '(',
#    'WP',
#    'VBD',
#    'IN',
#    'JJS',
#    'CD',
#    'NN',
#    'IN',
#    'NN',
#    ')',
#    'NN',
#    'IN',
#    'NNP',
#    'NNP',
#    'NN',
#    ',',
#    'NN',
#    'CC',
#    'NN',
#    'IN',
#    'NN',
#    '.'],
#   ['(',
#    '2',
#    ')',
#    'tvc',
#    ':',
#    'include',
#    'all',
#    'vaccinated',
#    'subject',
#    '(',
#    'who',
#    'receive',
#    'at',
#    'least',
#    'one',
#    'dose',
#    'of',
#    'vaccine',
#    ')',
#    'irrespective',
#    'of',
#    'hpv',
#    'dna',
#    'status',
#    ',',
#    'cytology',
#    'and',
#    'serostatus',
#    'at',
#    'baseline',
#    '.']),
#  (['(', 'atazanavir', '300', 'mg', 'and'],
#   ['(', 'VB', 'CD', 'NNS', 'CC'],
#   ['(', 'atazanavir', '300', 'mg', 'and'])]
# 'dev.en'
# [(['Slide', 'over', ',', 'honey', '.'],
#   ['NN', 'IN', ',', 'NN', '.'],
#   ['slide', 'over', ',', 'honey', '.']),
#  (['•',
#    'Where',
#    'the',
#    'Commission',
#    'ascertains',
#    'that',
#    'a',
#    'notified',
#    'body',
#    'does',
#    'not',
#    'meet',
#    'or',
#    'no',
#    'longer',
#    'meets',
#    'the',
#    'requirements',
#    'for',
#    'its',
#    'notification',
#    ',',
#    'it',
#    'shall',
#    'adopt',
#    'an',
#    'implementing',
#    'act',
#    'requesting',
#    'the',
#    'notifying',
#    'Member',
#    'State',
#    'to',
#    'take',
#    'the',
#    'necessary',
#    'corrective',
#    'measures',
#    ',',
#    'including',
#    'withdrawal',
#    'of',
#    'notification',
#    'if',
#    'necessary',
#    '.'],
#   ['NN',
#    'WRB',
#    'DT',
#    'NNP',
#    'VBZ',
#    'IN',
#    'DT',
#    'JJ',
#    'NN',
#    'VBZ',
#    'RB',
#    'VB',
#    'CC',
#    'DT',
#    'JJR',
#    'VBZ',
#    'DT',
#    'NNS',
#    'IN',
#    'PRP$',
#    'NN',
#    ',',
#    'PRP',
#    'MD',
#    'VB',
#    'DT',
#    'NN',
#    'NN',
#    'VBG',
#    'DT',
#    'JJ',
#    'NNP',
#    'NNP',
#    'TO',
#    'VB',
#    'DT',
#    'JJ',
#    'JJ',
#    'NNS',
#    ',',
#    'VBG',
#    'NN',
#    'IN',
#    'NN',
#    'IN',
#    'JJ',
#    '.'],
#   ['•',
#    'where',
#    'the',
#    'commission',
#    'ascertain',
#    'that',
#    'a',
#    'notified',
#    'body',
#    'do',
#    'not',
#    'meet',
#    'or',
#    'no',
#    'long',
#    'meet',
#    'the',
#    'requirement',
#    'for',
#    'it',
#    'notification',
#    ',',
#    'it',
#    'shall',
#    'adopt',
#    'an',
#    'implementing',
#    'act',
#    'request',
#    'the',
#    'notifying',
#    'member',
#    'state',
#    'to',
#    'take',
#    'the',
#    'necessary',
#    'corrective',
#    'measure',
#    ',',
#    'include',
#    'withdrawal',
#    'of',
#    'notification',
#    'if',
#    'necessary',
#    '.'])]
# 'test-opensubtitles.is'
# [(['Einhver',
#    'henti',
#    'múrsteini',
#    'inn',
#    'um',
#    'glugga',
#    'hjá',
#    'Meyer',
#    'Blum',
#    'í',
#    'nótt',
#    '.'],
#   ['foken',
#    'svg3eþ',
#    'nken',
#    'aa',
#    'ao',
#    'nkfo',
#    'aþ',
#    'e',
#    'e',
#    'aþ',
#    'nveo',
#    '.'],
#   ['einhver',
#    'henda',
#    'múrsteini',
#    'inn',
#    'um',
#    'gluggi',
#    'hjá',
#    'Meyer',
#    'Blum',
#    'í',
#    'nótt',
#    '.']),
#  (['Þeir', 'standa', 'sig', '.'],
#   ['fpkfn', 'sfg3fn', 'fpkfo', '.'],
#   ['hann', 'standa', 'sig', '.'])]
# 'test-ees.is'
# [(['Í',
#    '6.',
#    'kafla',
#    'I.',
#    'viðauka',
#    'við',
#    'tilskipun',
#    '92',
#    '/',
#    '118',
#    '/',
#    'EBE',
#    'er',
#    'mælt',
#    'fyrir',
#    'um',
#    'kröfur',
#    'vegna',
#    'innflutnings',
#    'á',
#    'unnu',
#    'dýraprótíni',
#    '.'],
#   ['aþ',
#    'ta',
#    'nkeþ',
#    'ta',
#    'nkee',
#    'ao',
#    'nveo',
#    'ta',
#    '/',
#    'ta',
#    '/',
#    'as',
#    'sfg3en',
#    'sþghen',
#    'aa',
#    'ao',
#    'nvfo',
#    'ae',
#    'nkee',
#    'aa',
#    'sfg3fþ',
#    'nheþ',
#    '.'],
#   ['í',
#    '6.',
#    'kafli',
#    'I.',
#    'viðauki',
#    'við',
#    'tilskipun',
#    '92',
#    '/',
#    '118',
#    '/',
#    'EBE',
#    'vera',
#    'mæla',
#    'fyrir',
#    'um',
#    'krafa',
#    'vegna',
#    'innflutningur',
#    'á',
#    'vinna',
#    'dýraprótín',
#    '.']),
#  (['Í',
#    'ákvörðun',
#    'framkvæmdastjórnarinnar',
#    '94',
#    '/',
#    '278',
#    '/',
#    'EB',
#    '(',
#    '3',
#    ')',
#    ',',
#    'eins',
#    'og',
#    'henni',
#    'var',
#    'síðast',
#    'breytt',
#    'með',
#    'ákvörðun',
#    '96',
#    '/',
#    '344',
#    '/',
#    'EB',
#    '(',
#    '4',
#    ')',
#    ',',
#    'er',
#    'mælt',
#    'fyrir',
#    'um',
#    'skrá',
#    'yfir',
#    'þriðju',
#    'lönd',
#    'sem',
#    'aðildarríkin',
#    'skulu',
#    'heimila',
#    'innflutning',
#    'frá',
#    'á',
#    'unnu',
#    'dýraprótíni',
#    'sem',
#    'ekki',
#    'er',
#    'ætlað',
#    'til',
#    'manneldis',
#    '.'],
#   ['aþ',
#    'nveþ',
#    'nveeg',
#    'ta',
#    '/',
#    'ta',
#    '/',
#    'as',
#    '(',
#    'ta',
#    ')',
#    ',',
#    'aa',
#    'c',
#    'fpveþ',
#    'sfg3eþ',
#    'aae',
#    'sþghen',
#    'aþ',
#    'nveo',
#    'ta',
#    '/',
#    'ta',
#    '/',
#    'as',
#    '(',
#    'ta',
#    ')',
#    ',',
#    'sfg3en',
#    'sþghen',
#    'aa',
#    'ao',
#    'nveo',
#    'ao',
#    'lhfovf',
#    'nhfo',
#    'ct',
#    'nhfng',
#    'sfg3fn',
#    'sng',
#    'nkeo',
#    'aa',
#    'aa',
#    'sfg3fþ',
#    'nken',
#    'ct',
#    'aa',
#    'sfg3en',
#    'sþghen',
#    'ae',
#    'nhee',
#    '.'],
#   ['í',
#    'ákvörðun',
#    'framkvæmdastjórn',
#    '94',
#    '/',
#    '278',
#    '/',
#    'EB',
#    '(',
#    '3',
#    ')',
#    ',',
#    'eins',
#    'og',
#    'hún',
#    'vera',
#    'síðar',
#    'breyta',
#    'með',
#    'ákvörðun',
#    '96',
#    '/',
#    '344',
#    '/',
#    'EB',
#    '(',
#    '4',
#    ')',
#    ',',
#    'vera',
#    'mæla',
#    'fyrir',
#    'um',
#    'skrá',
#    'yfir',
#    'þriðji',
#    'land',
#    'sem',
#    'aðildarríki',
#    'skulu',
#    'heimila',
#    'innflutningur',
#    'frá',
#    'á',
#    'vinna',
#    'dýraprótíni',
#    'sem',
#    'ekki',
#    'vera',
#    'ætla',
#    'til',
#    'manneldi',
#    '.'])]
# 'test-ema.is'
# [(['(',
#    '2',
#    ')',
#    'Heildarþýði',
#    'bólusettra',
#    ':',
#    'í',
#    'hópnum',
#    'voru',
#    'allir',
#    'sem',
#    'voru',
#    'bólusettir',
#    '(',
#    'fengu',
#    'a.m.k.',
#    'einn',
#    'skammt',
#    'af',
#    'bóluefninu',
#    ')',
#    ',',
#    'óháð',
#    'HPV-DNA-stöðu',
#    'þeirra',
#    ',',
#    'frumufræðilegum',
#    'greiningum',
#    'og',
#    'mótefnastöðu',
#    'í',
#    'upphafi',
#    '.'],
#   ['(',
#    'ta',
#    ')',
#    'nhen',
#    'lkfesf',
#    ':',
#    'aþ',
#    'nkeþg',
#    'sfg3fþ',
#    'fokfn',
#    'ct',
#    'sfg3fþ',
#    'sþgkfn',
#    '(',
#    'sfg3fþ',
#    'as',
#    'tfkeo',
#    'aa',
#    'aþ',
#    'nheþg',
#    ')',
#    ',',
#    'aþ',
#    'nveþ-s',
#    'fpvfe',
#    ',',
#    'lvfþsf',
#    'nvfþ',
#    'c',
#    'nveþ',
#    'aþ',
#    'nheþ',
#    '.'],
#   ['(',
#    '2',
#    ')',
#    'heildarþýði',
#    'bólusettur',
#    ':',
#    'í',
#    'hópur',
#    'vera',
#    'allur',
#    'sem',
#    'vera',
#    'bólusetja',
#    '(',
#    'fá',
#    'a.m.k.',
#    'einn',
#    'skammt',
#    'af',
#    'bóluefni',
#    ')',
#    ',',
#    'óháð',
#    'HPV-DNA-staða',
#    'hún',
#    ',',
#    'frumufræðilegur',
#    'greining',
#    'og',
#    'mótefnastaða',
#    'í',
#    'upphaf',
#    '.']),
#  (['viku', '(', 'atazanavír', '300', 'mg', 'og'],
#   ['nveþ', '(', 'nken', 'ta', 'as', 'c'],
#   ['vika', '(', 'atazanavír', '300', 'mg', 'og'])]
# 'train.is'
# [(['FYRRI', 'ÞÁTTUR'], ['e', 'nken'], ['FYRRI', 'þáttur']),
#  (['I.', 'Veizlan', 'í', 'nýju', 'höllinni', '.'],
#   ['ta', 'nveng', 'aþ', 'lveþvf', 'nveþg', '.'],
#   ['I.', 'veizla', 'í', 'nýr', 'höll', '.'])]
# 'dev.is'
# [(['Færðu', 'þig', ',', 'ástin', '.'],
#   ['sfg2en', 'fp2eo', ',', 'nveng', '.'],
#   ['fá', 'þú', ',', 'ást', '.']),
#  (['•',
#    'Ef',
#    'framkvæmdastjórnin',
#    'kemst',
#    'að',
#    'raun',
#    'um',
#    'að',
#    'tilkynnt',
#    'stofa',
#    'uppfylli',
#    'ekki',
#    ',',
#    'eða',
#    'uppfylli',
#    'ekki',
#    'lengur',
#    ',',
#    'kröfurnar',
#    'viðvíkjandi',
#    'tilkynningu',
#    'hennar',
#    ',',
#    'skal',
#    'hún',
#    'samþykkja',
#    'framkvæmdargerð',
#    'þar',
#    'sem',
#    'óskað',
#    'er',
#    'eftir',
#    'því',
#    'að',
#    'tilkynningaraðildarríkið',
#    'geri',
#    'nauðsynlegar',
#    'ráðstafanir',
#    'til',
#    'úrbóta',
#    ',',
#    'þ.m.t.',
#    'að',
#    'afturkalla',
#    'tilkynningu',
#    ',',
#    'ef',
#    'nauðsyn',
#    'krefur',
#    '.'],
#   ['as',
#    'c',
#    'nveng',
#    'sfm3en',
#    'aþ',
#    'nveþ',
#    'ao',
#    'c',
#    'sþgven',
#    'nven',
#    'svg3en',
#    'aa',
#    ',',
#    'c',
#    'svg3en',
#    'aa',
#    'aam',
#    ',',
#    'nvfng',
#    'slg',
#    'nveo',
#    'fpvee',
#    ',',
#    'sfg3en',
#    'fpven',
#    'sng',
#    'nveo',
#    'aa',
#    'c',
#    'sþghen',
#    'sfg3en',
#    'aþ',
#    'fpheþ',
#    'c',
#    'nheng',
#    'svg3en',
#    'lvfosf',
#    'nvfo',
#    'ae',
#    'nvfe',
#    ',',
#    'as',
#    'cn',
#    'sng',
#    'nveo',
#    ',',
#    'c',
#    'nven',
#    'sfg3en',
#    '.'],
#   ['•',
#    'ef',
#    'framkvæmdastjórn',
#    'koma',
#    'að',
#    'raun',
#    'um',
#    'að',
#    'tilkynna',
#    'stofa',
#    'uppfylla',
#    'ekki',
#    ',',
#    'eða',
#    'uppfylla',
#    'ekki',
#    'lengi',
#    ',',
#    'krafa',
#    'viðvíkja',
#    'tilkynning',
#    'hún',
#    ',',
#    'skulu',
#    'hún',
#    'samþykkja',
#    'framkvæmdargerð',
#    'þar',
#    'sem',
#    'óska',
#    'vera',
#    'eftir',
#    'það',
#    'að',
#    'tilkynningaraðildarríki',
#    'gera',
#    'nauðsynlegur',
#    'ráðstöfun',
#    'til',
#    'úrbót',
#    ',',
#    'þ.m.t.',
#    'að',
#    'afturkalla',
#    'tilkynning',
#    ',',
#    'ef',
#    'nauðsyn',
#    'krefja',
#    '.'])]
