# %%
# !conda create --name notebook -y python==3.7.5 ipykernel
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/staff/haukurpj/.conda/envs/notebook
#
#   added / updated specs:
#     - ipykernel
#     - python==3.7.5
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ipykernel-5.1.3            |   py37h39e3cac_0         167 KB
#     ipython-7.10.1             |   py37h39e3cac_0         1.1 MB
#     jupyter_core-4.6.1         |           py37_0          74 KB
#     six-1.13.0                 |           py37_0          27 KB
#     ------------------------------------------------------------
#                                            Total:         1.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   backcall           pkgs/main/linux-64::backcall-0.1.0-py37_0
# ...

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/56/a0/dbcf5881bb2f51e8db678211907f16ea0a182b232c591a6d6f276985ca95/ipywidgets-7.5.1-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/83/df/0f5dd132200728a86190397e1ea87cd76244e42d39ec5e88efd25b2abd7e/jupyter-1.0.0-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/cb/ee/6374ae8c21b7d0847f9c3722dcdfac986b8e54fa9ad9ea66e1eb6320d2b8/jupyter_console-6.0.0-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/93/f8/518fb0bb89860eea6ff1b96483fbd9236d5ee991485d0f3eceff1770f654/kiwisolver-1.1.0-cp37-cp37m-manylinux1_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/61/42/3e92d7aa64295483fbca20a86c89b34d0cb43cffaadaffe028793902d790/matplotlib-3.1.2-cp37-cp37m-manylinux1_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/f5/69/d2ffaf7efc20ce47469187e3a41e6e03e17b45de5a6559f4e7ab3eace5e1/notebook-6.0.2-py3-none-any.whl
# ...

# %%
# !pip uninstall -y frontend
# !pip install git+https://github.com/cadia-lvl/SMT.git@v2.1.0#egg=frontend\&subdirectory=frontend
# Out:
# Uninstalling frontend-2.0.7:
#   Successfully uninstalled frontend-2.0.7
# ...
#   Cloning https://github.com/cadia-lvl/SMT.git (to revision v2.1.0) to /tmp/pip-install-sxee9m3h/frontend
#   Running command git clone -q https://github.com/cadia-lvl/SMT.git /tmp/pip-install-sxee9m3h/frontend
# ...
#      |████████████████████████████████| 112kB 896kB/s eta 0:00:01
# ...
#   Created wheel for frontend: filename=frontend-2.0.8-cp37-none-any.whl size=19015 sha256=92c4bd8f4bfb6710c9c3059823a5328ac6e61ed485c0e27bd25b14db9b8c9f84
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fh58vkqz/wheels/4f/55/bd/bef7ff6a4c813b07695dfbd0c8fe324e22fdc9569a4fd4a8f9
# Successfully built frontend
# ...
#   Found existing installation: tokenizer 2.0.1
#     Uninstalling tokenizer-2.0.1:
#       Successfully uninstalled tokenizer-2.0.1
# ...

# %%
# !pip install --upgrade tokenizer
# Out:
# ...
#      |████████████████████████████████| 112kB 896kB/s eta 0:00:01
# ...
#   Found existing installation: tokenizer 2.0.0
#     Uninstalling tokenizer-2.0.0:
#       Successfully uninstalled tokenizer-2.0.0
# ...

# %%
# !pip install pandas
# Out:
# ...
#      |████████████████████████████████| 10.4MB 297kB/s eta 0:00:01
# ...
